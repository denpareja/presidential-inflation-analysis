# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import os

# 1) Paths (asumiendo que abriste la carpeta raíz en VSCode)
approval_path = os.path.join("data", "raw", "approval.csv")
inflation_path = os.path.join("data", "raw", "inflation.csv")

# 2) Load data
approval = pd.read_csv(approval_path)
infl = pd.read_csv(inflation_path)

print("Approval shape:", approval.shape)
print("Inflation shape:", infl.shape)

display(approval.head())
display(infl.head())
